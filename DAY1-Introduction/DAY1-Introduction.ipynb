# %% [markdown]
# # 第一天 `numpy`和`matplot`简介
# ## 任务：
# - 用随机数画一个散点图
# - 用折线图表示一个函数

# %%
import numpy as np #导入numpy写作np

# %%
# 查看numpy的版本来验证是否导入成功
np.__version__
# Out:
# '1.20.1'

# %% [markdown]
# ## 用`np.random.rand()`生成一个随机数，储存在变量x中

# %%
x_random = np.random.rand()
# 用print显示出来
print(x_random)
# Out:
# 0.6735303918834681

# %% [markdown]
# 注意：每次运行都会生成一个新的随机数，如果希望固定结果，需要用随机数种子seed

# %% [markdown]
# ### 可以生成一个随机数矩阵

# %%
X_random = np.random.rand(3,3) # 3×3的矩阵

# %%
X_random
# Out:
# array([[0.1827071 , 0.03233371, 0.99829569],
#        [0.79948473, 0.80696411, 0.13380712],
#        [0.28877324, 0.34408752, 0.04780142]])

# %% [markdown]
# 默认0-1，均匀分布均值为0.5

# %% [markdown]
# ## 用`matplot`绘图

# %%
import matplotlib.pyplot as plt # 导入matplot中的pyplot，写作plt

# %% [markdown]
# ### 生成一个100个数的列向量`x_random`和`y_random`

# %%
x_random_uniform = np.random.rand(1000)
y_random_uniform = np.random.rand(1000)

# %%
x_random_uniform
# Out:
# array([3.12706005e-01, 8.70134405e-01, 5.44162965e-01, 3.75733787e-02,
#        6.71235193e-01, 3.79273529e-01, 5.77274678e-01, 5.87138998e-01,
#        9.33987095e-01, 5.22181032e-01, 8.21773401e-01, 2.96838009e-01,
#        9.23355147e-01, 1.24037241e-01, 9.17165147e-02, 4.99687040e-01,
#        2.13958405e-01, 8.56815616e-01, 9.68934884e-01, 7.14565518e-01,
#        9.77500519e-02, 8.76786830e-01, 7.10549401e-01, 5.09199817e-01,
#        7.58367967e-01, 1.61105003e-01, 6.47756361e-01, 5.27429278e-01,
#        5.66401142e-01, 6.24090327e-01, 6.55651240e-01, 9.64488257e-02,
#        6.62310886e-01, 4.21671492e-01, 1.24467241e-01, 3.53181728e-01,
#        5.24448441e-01, 6.26674645e-02, 2.00150814e-01, 5.51080286e-01,
#        2.74183079e-01, 6.92560751e-01, 6.74754570e-01, 8.50844443e-01,
#        5.64026331e-01, 8.45042200e-01, 5.20453146e-01, 7.14467907e-01,
#        1.25054369e-01, 3.20237921e-01, 2.17868471e-01, 3.29772910e-01,
# ...

# %%
plt.scatter(x_random_uniform, y_random_uniform) #画散点图
plt.show() #表示显示在屏幕上

# %% [markdown]
# 上述结果为均匀分布`np.random.rand`
# 正态分布`np.random.randn`

# %%
x_random_normal = np.random.randn(1000)
y_random_normal = np.random.randn(1000)

# %%
plt.scatter(x_random_normal, y_random_normal) #画散点图
plt.show() #表示显示在屏幕上
